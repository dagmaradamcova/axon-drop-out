# %% [markdown]
# ## Data Preprocessing
#
# This notebook contains code for data cleaning and ratio computation over the original [data set](https://osf.io/xsb6g/) and produces a CSV file used in our main analyses.

# %%
import pandas as pd
import numpy as np

# %%
# LOAD DATA

df = pd.read_csv('data/v2merged.csv', usecols=['ga:eventAction', 'ga:eventLabel', 'ga:eventValue']) 
df = df.rename(columns={'ga:eventAction': 'id', 'ga:eventLabel': 'attempt', 'ga:eventValue': 'score'}) # rename columns 

print('data loaded')
# Out:
# data loaded

# %% [markdown]
# ### Data Cleaning

# %%
# %%time

# 1. FILTER OUT PLAYERS WITH LESS THAN 3 AND MORE THAN 200 ATTEMPTS
counts = df.groupby('id')['attempt'].count().reset_index()
ids1 = counts.drop(counts[(counts.attempt < 3) | (counts.attempt > 200)].index) # filter for n attempts 
mask = df['id'].isin(ids1.id)

# 2. FILTER OUT PLAYERS WHO SCORED 176 IN ALL ATTEMPTS (NULL SCORES)
# 176 is the score players receive when they start the game but never actually play (timer runs out before they click on a protein target) 
ids2 = df[mask].groupby('id').apply(lambda x: ~((x.score == 176.0).all()))

ids1 = ids1.set_index('id') 
ids2 = pd.DataFrame(ids2, columns=['bool176']) 
ids1 = ids1.join(ids2) 
ids1.drop(ids1[ids1.bool176==False].index, inplace=True) # drop players who scored 176 in all attempts

# 3. FILTER OUT PLAYERS WITH NaNs
nans = df[df.score.isnull()] # find NaNs
nans_array = nans.id.values
ids1 = ids1.reset_index()
ids1.drop(ids1[ids1.id.isin(nans_array)].index, inplace=True) # drop IDs with NaNs

mask = df['id'].isin(ids1.id) # update mask
# Out:
# CPU times: user 2min 37s, sys: 1.81 s, total: 2min 39s
# Wall time: 2min 41s

# %%
grouped = df[mask].groupby('id') # apply mask and group by id

# %%
print('N OF PLAYERS AFTER MASKING: ', grouped.ngroups)
# Out:
# N OF PLAYERS AFTER MASKING:  460435

# %% [markdown]
# ### Score Ratio Computation

# %%
# DEFINE SCORE RATIO FUNCTION

def running_best_score(sf):
    sf = sf.sort_values('attempt')
    sf['quit'] = 0
    sf.set_value(sf[sf['attempt']==sf['attempt'].max()].index, 'quit', '1') # mark quit as 1 for last game 
    sf['rolling_max'] = pd.rolling_max(sf['score'], window=len(sf), min_periods=1)
    sf['ratio'] = np.NaN
    sf['ratio'][1:] = sf['score'][1:].values / sf['rolling_max'][:-1].values    
    return sf

# %%
# %%time

# CALC SCORE RATIOS 
# this cell takes approx. 40 mins to run (but time varies depending on sample size and pc configuration) 

outdf = grouped.apply(running_best_score)
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=4,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=3,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=8,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=9,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=6,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=19,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=5,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=22,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=57,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=10,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=18,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=16,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=7,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=11,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=63,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=29,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=21,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=151,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=24,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=28,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=43,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=119,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=33,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=51,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=20,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=25,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=45,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=13,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=17,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=35,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=31,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=15,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=14,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=48,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=23,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=132,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=84,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=92,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=64,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=27,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=40,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=53,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=32,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=153,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=76,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=39,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=30,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=62,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=42,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=26,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=85,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=34,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=52,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=36,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=38,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=194,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=71,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=167,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=41,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=65,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=60,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=89,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=165,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=77,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=70,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=44,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=73,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=69,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=112,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=54,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=116,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=37,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=99,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=66,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=109,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=59,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=67,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=86,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=78,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=49,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=83,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=104,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=144,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=186,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=156,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=121,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=55,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=81,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=61,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=136,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=46,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=47,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=82,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=58,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=94,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=134,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=110,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=80,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=177,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=68,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=138,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=97,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=72,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=90,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=117,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=74,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=56,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=125,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=118,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=133,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=180,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=88,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=129,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=161,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=131,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=183,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=102,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=105,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=87,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=98,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=139,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=176,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=95,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=122,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=123,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=127,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=79,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=100,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=172,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=108,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=199,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=96,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=115,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=188,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=107,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=111,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=148,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=160,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=114,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=169,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=155,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=146,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=101,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=113,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=170,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=128,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=75,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=93,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=159,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=168,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=106,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=157,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=185,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=142,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=190,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=91,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=124,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=147,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=149,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=130,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=103,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=192,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=171,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=126,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=181,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=196,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=158,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=191,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=140,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=162,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=175,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=166,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=120,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=178,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=137,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=163,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=135,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=145,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=198,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=174,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=141,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=150,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=154,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=195,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=184,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=182,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=189,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=197,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=164,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=143,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=152,min_periods=1,center=False).max()
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=173,min_periods=1,center=False).max()
#   import sys
# CPU times: user 42min 32s, sys: 21.4 s, total: 42min 53s
# Wall time: 42min 59s

# %% [markdown]
# ### Save To CSV

# %%
outdf.to_csv('data/outdf.csv') # make sure your paths match
